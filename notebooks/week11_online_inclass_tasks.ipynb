# %% [markdown]
# <a href="https://colab.research.google.com/github/stevenolanecon/7002LBSAI/blob/main/notebooks/week11_online_inclass_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Before you start:**
#
# - Go to **File → Save a copy in Drive**. Until you do this, your work only exists in this browser tab – you can't save changes back to GitHub, and closing the tab or losing the session will lose your work.
# - Turn off Colab's autocomplete: **Tools → Settings → Editor → uncheck "Show context-powered code completions."** It's a setting on your own Google account, not something built into this notebook, so you'll need to do it once per account.

# %% [markdown]
# # Week 11 online – In-class task
#
# Continues from the swimming-pool ticket-sales example used earlier in this session – same training/test split, same holdout.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

data_path = "https://raw.githubusercontent.com/stevenolanecon/7002LBSAI/main/data/swim_tickets.csv"
swim_df = pd.read_csv(data_path, parse_dates=['date'])
swim_df['month'] = swim_df['date'].dt.month
swim_df['dow'] = swim_df['date'].dt.dayofweek
swim_df['t'] = range(len(swim_df))

train = swim_df[swim_df.date < '2016-01-01']
test = swim_df[swim_df.date >= '2016-01-01']
train.head()

# %% [markdown]
# ## Task – does trend even matter here?
#
# **Business question:** is the linear trend term pulling its weight, or is seasonality carrying the whole model?
#
# The full model already fitted earlier in this session was `tickets ~ t + C(month)` (trend plus month dummies). Fit `tickets ~ C(month)` – month dummies only, no trend – on the same training data, and check its RMSE on the same 2016 holdout (`test`). How does it compare to the full model above?

# %% [markdown]
# *Your RMSE for the month-only model, and what it tells you about whether the trend term was doing any real work:*
