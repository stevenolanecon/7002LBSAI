# %% [markdown]
# <a href="https://colab.research.google.com/github/stevenolanecon/7002LBSAI/blob/main/notebooks/week11_inclass_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Before you start:**
#
# - Go to **File → Save a copy in Drive**. Until you do this, your work only exists in this browser tab – you can't save changes back to GitHub, and closing the tab or losing the session will lose your work.
# - Turn off Colab's autocomplete: **Tools → Settings → Editor → uncheck "Show context-powered code completions."** It's a setting on your own Google account, not something built into this notebook, so you'll need to do it once per account.

# %% [markdown]
# # Week 11 – In-class tasks
#
# Work through these during the workshop, alongside the slides.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data_path = "https://raw.githubusercontent.com/stevenolanecon/7002LBSAI/main/data/arizona_electricity.csv"
az_df = pd.read_csv(data_path, parse_dates=['date'])
az_df.head()

# %% [markdown]
# ## Task 1 – simulate a random walk yourself
#
# **Business question:** what does "impossible to predict" actually look like, generated from scratch?
#
# Using `numpy`, generate 100 random shocks (`np.random.normal`), turn them into a random walk with `np.cumsum`, and plot it with `matplotlib`. Then generate a second series that's just the raw shocks, unsummed, and plot that alongside it. What's different about the two?

# %% [markdown]
# ## Task 2 – absolute vs. relative differences
#
# **Business question:** which transformation actually stabilises a time series – and does it matter which one you pick?
#
# Using the Arizona electricity data (`az_df`), compute both `.diff()` (absolute) and `.pct_change()` (relative, ×100) on `Q`, the monthly consumption. Plot the two transformed series against the raw levels. Does either look more stable?

# %% [markdown]
# *Which transformation looked more stable, and why do you think that is?*
