# %% [markdown]
# <a href="https://colab.research.google.com/github/stevenolanecon/7002LBSAI/blob/main/notebooks/7002LBSAI_Week_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
measurement_data = "https://raw.githubusercontent.com/stevenolanecon/7002LBSAI/main/data/synthetic_reaction_times.csv"
