# %% [markdown]
# <a href="https://colab.research.google.com/github/stevenolanecon/7002LBSAI/blob/main/notebooks/week10_inclass_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Before you start:**
#
# - Go to **File → Save a copy in Drive**. Until you do this, your work only exists in this browser tab – you can't save changes back to GitHub, and closing the tab or losing the session will lose your work.
# - Turn off Colab's autocomplete: **Tools → Settings → Editor → uncheck "Show context-powered code completions."** It's a setting on your own Google account, not something built into this notebook, so you'll need to do it once per account.

# %% [markdown]
# # Week 10 – In-class tasks
#
# Work through these during the workshop, alongside the slides.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
from sklearn.model_selection import KFold

data_path = "https://raw.githubusercontent.com/stevenolanecon/7002LBSAI/main/data/used_cars_chicago.csv"
df = pd.read_csv(data_path)
df.head()

# %% [markdown]
# ## Task 1 – fit Model 1 and Model 3 yourself
#
# **Business question:** how much does adding mileage, trim, and condition actually improve the fit?
#
# Fit Model 1 (`price ~ age + agesq`) and Model 3 (add `odometer`, `odometersq`, `LE`, `cond_excellent`, `cond_good`, `dealer`) with `smf.ols`. Compute the **in-sample RMSE** for each from the residuals – don't use a library shortcut.

# %% [markdown]
# ## Task 2 – write your own 5-fold cross-validation
#
# **Business question:** does Model 3's advantage over Model 1 survive being tested on data it didn't train on?
#
# For **Model 1** and **Model 3** separately: fill in the model formula and the final averaging step below, run the 5-fold loop, and compare the two cross-validated RMSEs. No further syntax hints beyond what you've already seen – this is the same template from the slide.

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=1)

rmses = []
for train_idx, test_idx in kf.split(df):
    train, test = df.iloc[train_idx], df.iloc[test_idx]
    model = smf.ols(_____, data=train).fit()
    pred = model.predict(test)
    fold_rmse = np.sqrt(np.mean((test['price'] - pred) ** 2))
    rmses.append(fold_rmse)

cv_rmse = _____

# %% [markdown]
# *Your two cross-validated RMSEs (Model 1 vs. Model 3), and whether Model 3's advantage survives:*
